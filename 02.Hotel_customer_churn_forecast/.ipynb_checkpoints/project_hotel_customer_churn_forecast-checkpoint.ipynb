# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
#  <b>Добрый день, Алексей!</b>
#
# Меня зовут Ксения Цыганова, и я буду комментировать твою работу и помогать тебе сделать ее сильнее. В Практикуме мы общаемся на «ты», но если тебе это будет некомфортно, пожалуйста, скажи, и мы будем обращаться друг к другу на «вы».
#
# Все мои комментарии делятся на три вида:
#
#
# 👍 Здесь все отлично, идем дальше! - <font color='green'> зеленый цвет </font>
#
# 💡 Все хорошо, однако, можно оптимизировать или рассмотреть другие способы (необязательно для исполнения, чтобы пройти дальше) - <font color='gold'>желтый цвет</font>
#
# 🤔 Необходимо внести исправления, без которых я не смогу принять проект - <font color='red'>красный цвет</font>
#
#
# Свои комментарии я буду выделять заголовком «комментарий ревьюера». Пожалуйста, не удаляй их, это поможет сократить время проверки на повторных ревью.Ты также можешь писать свои комментарии к моим и выделять их любым понравившимся способом, отличным от моего. Если у тебя будут возникать вопросы в течение нашей работы, я с радостью на них отвечу.
#
# Цель моего ревью не критика и не возможность дать тебе готовые ответы, это способ привести тебя в нужное русло, чтобы ты смог развить собственные идеи и решения. Твой будущий работодатель будет поступать похожим образом.
#
#    <b>У тебя все получится!</b>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b> Комментарий студента: </b> Ксения, спасибо за ревью и советы,в т.ч. по оптимизации. Комментарии касающиеся доработки поправил. Комментарии с желтым цветом учту для будущих проектов.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# Алексей, рада помочь!

# %% [markdown]
# <h1>Содрежание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Шаг-1.-Откройте-файлы-с-данными" data-toc-modified-id="Шаг-1.-Откройте-файлы-с-данными-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Шаг 1. Откройте файлы с данными</a></span></li><li><span><a href="#Шаг-2.-Предобработка-и-исследовательский-анализ-данных" data-toc-modified-id="Шаг-2.-Предобработка-и-исследовательский-анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Шаг 2. Предобработка и исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Предобработка-обучающей-выборки" data-toc-modified-id="Предобработка-обучающей-выборки-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Предобработка обучающей выборки</a></span></li><li><span><a href="#Предобработка-тестовой-выборки" data-toc-modified-id="Предобработка-тестовой-выборки-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Предобработка тестовой выборки</a></span></li><li><span><a href="#Исследование-связи-целевого-признака-с-прочими" data-toc-modified-id="Исследование-связи-целевого-признака-с-прочими-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Исследование связи целевого признака с прочими</a></span><ul class="toc-item"><li><span><a href="#Месяц-заезда-(arrival_date_month)" data-toc-modified-id="Месяц-заезда-(arrival_date_month)-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Месяц заезда (arrival_date_month)</a></span></li><li><span><a href="#Опции-заказа-(meal)" data-toc-modified-id="Опции-заказа-(meal)-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Опции заказа (meal)</a></span></li><li><span><a href="#Год-заезда-(arrival_date_year)" data-toc-modified-id="Год-заезда-(arrival_date_year)-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>Год заезда (arrival_date_year)</a></span></li><li><span><a href="#Количество-дней-между-датой-бронирования-и-датой-прибытия-(lead_time)" data-toc-modified-id="Количество-дней-между-датой-бронирования-и-датой-прибытия-(lead_time)-2.3.4"><span class="toc-item-num">2.3.4&nbsp;&nbsp;</span>Количество дней между датой бронирования и датой прибытия (lead_time)</a></span></li><li><span><a href="#Неделя-заезда-(arrival_date_week_number)" data-toc-modified-id="Неделя-заезда-(arrival_date_week_number)-2.3.5"><span class="toc-item-num">2.3.5&nbsp;&nbsp;</span>Неделя заезда (arrival_date_week_number)</a></span></li><li><span><a href="#День-заезда-(arrival_date_day_of_month)" data-toc-modified-id="День-заезда-(arrival_date_day_of_month)-2.3.6"><span class="toc-item-num">2.3.6&nbsp;&nbsp;</span>День заезда (arrival_date_day_of_month)</a></span></li><li><span><a href="#Количество-ночей-в-выходные-дни-(stays_in_weekend_nights)" data-toc-modified-id="Количество-ночей-в-выходные-дни-(stays_in_weekend_nights)-2.3.7"><span class="toc-item-num">2.3.7&nbsp;&nbsp;</span>Количество ночей в выходные дни (stays_in_weekend_nights)</a></span></li><li><span><a href="#Количество-ночей-в-будние-дни-(stays_in_week_nights)" data-toc-modified-id="Количество-ночей-в-будние-дни-(stays_in_week_nights)-2.3.8"><span class="toc-item-num">2.3.8&nbsp;&nbsp;</span>Количество ночей в будние дни (stays_in_week_nights)</a></span></li><li><span><a href="#Количество-взрослых-постояльцев-(adults)" data-toc-modified-id="Количество-взрослых-постояльцев-(adults)-2.3.9"><span class="toc-item-num">2.3.9&nbsp;&nbsp;</span>Количество взрослых постояльцев (adults)</a></span></li><li><span><a href="#Количество-детей-от-3-до-14-лет-(children)" data-toc-modified-id="Количество-детей-от-3-до-14-лет-(children)-2.3.10"><span class="toc-item-num">2.3.10&nbsp;&nbsp;</span>Количество детей от 3 до 14 лет (children)</a></span></li><li><span><a href="#Количество-младенцев-(babies)" data-toc-modified-id="Количество-младенцев-(babies)-2.3.11"><span class="toc-item-num">2.3.11&nbsp;&nbsp;</span>Количество младенцев (babies)</a></span></li><li><span><a href="#Повтроный-клиент-или-нет-(is_repeated_guest)" data-toc-modified-id="Повтроный-клиент-или-нет-(is_repeated_guest)-2.3.12"><span class="toc-item-num">2.3.12&nbsp;&nbsp;</span>Повтроный клиент или нет (is_repeated_guest)</a></span></li><li><span><a href="#Количество-отменённых-заказов-у-клиента-(previous_cancellations)" data-toc-modified-id="Количество-отменённых-заказов-у-клиента-(previous_cancellations)-2.3.13"><span class="toc-item-num">2.3.13&nbsp;&nbsp;</span>Количество отменённых заказов у клиента (previous_cancellations)</a></span></li><li><span><a href="#Количество-подтверждённых-заказов-у-клиента-(previous_bookings_not_canceled)" data-toc-modified-id="Количество-подтверждённых-заказов-у-клиента-(previous_bookings_not_canceled)-2.3.14"><span class="toc-item-num">2.3.14&nbsp;&nbsp;</span>Количество подтверждённых заказов у клиента (previous_bookings_not_canceled)</a></span></li><li><span><a href="#Количество-изменений-параметров-заказа-(booking_changes)" data-toc-modified-id="Количество-изменений-параметров-заказа-(booking_changes)-2.3.15"><span class="toc-item-num">2.3.15&nbsp;&nbsp;</span>Количество изменений параметров заказа (booking_changes)</a></span></li><li><span><a href="#Количество-дней-ожидания-подтвреждения-(days_in_waiting_list)" data-toc-modified-id="Количество-дней-ожидания-подтвреждения-(days_in_waiting_list)-2.3.16"><span class="toc-item-num">2.3.16&nbsp;&nbsp;</span>Количество дней ожидания подтвреждения (days_in_waiting_list)</a></span></li><li><span><a href="#Необходимость-места-для-автомобиля-(required_car_parking_spaces)" data-toc-modified-id="Необходимость-места-для-автомобиля-(required_car_parking_spaces)-2.3.17"><span class="toc-item-num">2.3.17&nbsp;&nbsp;</span>Необходимость места для автомобиля (required_car_parking_spaces)</a></span></li><li><span><a href="#Количество-специальных-отметок-(total_of_special_requests)" data-toc-modified-id="Количество-специальных-отметок-(total_of_special_requests)-2.3.18"><span class="toc-item-num">2.3.18&nbsp;&nbsp;</span>Количество специальных отметок (total_of_special_requests)</a></span></li><li><span><a href="#Общее-количество-ночей-(total_nights)" data-toc-modified-id="Общее-количество-ночей-(total_nights)-2.3.19"><span class="toc-item-num">2.3.19&nbsp;&nbsp;</span>Общее количество ночей (total_nights)</a></span></li></ul></li><li><span><a href="#Вывод-по-результатам-предобработки-и-исследования-целевого-признака" data-toc-modified-id="Вывод-по-результатам-предобработки-и-исследования-целевого-признака-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Вывод по результатам предобработки и исследования целевого признака</a></span></li></ul></li><li><span><a href="#Шаг-3.-Формулировка-ML-задачи-на-основе-бизнес-задачи" data-toc-modified-id="Шаг-3.-Формулировка-ML-задачи-на-основе-бизнес-задачи-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Шаг 3. Формулировка ML-задачи на основе бизнес-задачи</a></span></li><li><span><a href="#Шаг-4.-Разработка-модели-ML" data-toc-modified-id="Шаг-4.-Разработка-модели-ML-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Шаг 4. Разработка модели ML</a></span><ul class="toc-item"><li><span><a href="#Случайный-лес-с-балансировкой-весов-c-применением-техники-OHE-и-StandardScaler-для-кодирования-и-масштабирования-данных" data-toc-modified-id="Случайный-лес-с-балансировкой-весов-c-применением-техники-OHE-и-StandardScaler-для-кодирования-и-масштабирования-данных-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Случайный лес с балансировкой весов c применением техники OHE и StandardScaler для кодирования и масштабирования данных</a></span></li><li><span><a href="#Случайный-лес-с-балансировкой-весов-c-применением-техники-OrdinalEncoder-и-MinMaxScaler-для-кодирования-и-масштабирования-данных" data-toc-modified-id="Случайный-лес-с-балансировкой-весов-c-применением-техники-OrdinalEncoder-и-MinMaxScaler-для-кодирования-и-масштабирования-данных-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Случайный лес с балансировкой весов c применением техники OrdinalEncoder и MinMaxScaler для кодирования и масштабирования данных</a></span></li><li><span><a href="#Логистическая-регрессия-с-балансировкой-весов-c-применением-техники-OHE-и-StandardScaler-для-кодирования-и-масштабирования-данных" data-toc-modified-id="Логистическая-регрессия-с-балансировкой-весов-c-применением-техники-OHE-и-StandardScaler-для-кодирования-и-масштабирования-данных-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Логистическая регрессия с балансировкой весов c применением техники OHE и StandardScaler для кодирования и масштабирования данных</a></span></li><li><span><a href="#Логистическая-регрессия-с-балансировкой-весов-c-применением-техники-OrdinalEncoder-и-MinMaxScaler-для-кодирования-и-масштабирования-данных" data-toc-modified-id="Логистическая-регрессия-с-балансировкой-весов-c-применением-техники-OrdinalEncoder-и-MinMaxScaler-для-кодирования-и-масштабирования-данных-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Логистическая регрессия с балансировкой весов c применением техники OrdinalEncoder и MinMaxScaler для кодирования и масштабирования данных</a></span></li><li><span><a href="#Обобщение-результататов-обучения" data-toc-modified-id="Обобщение-результататов-обучения-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Обобщение результататов обучения</a></span></li><li><span><a href="#Тестирование-модели" data-toc-modified-id="Тестирование-модели-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Тестирование модели</a></span></li><li><span><a href="#Оценка-прибыли" data-toc-modified-id="Оценка-прибыли-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Оценка прибыли</a></span></li><li><span><a href="#Вывод-по-результатам-шага" data-toc-modified-id="Вывод-по-результатам-шага-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Вывод по результатам шага</a></span></li></ul></li><li><span><a href="#Шаг-5.-Опишите-портрет-«ненадёжного»-клиента" data-toc-modified-id="Шаг-5.-Опишите-портрет-«ненадёжного»-клиента-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Шаг 5. Опишите портрет «ненадёжного» клиента</a></span></li><li><span><a href="#Шаг-6.-Напишите-общий-вывод" data-toc-modified-id="Шаг-6.-Напишите-общий-вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Шаг 6. Напишите общий вывод</a></span></li></ul></div>

# %% [markdown]
# # Прогнозирование оттока клиентов в сети отелей «Как в гостях»

# %% [markdown]
# **Описание проекта**
#
# Заказчик этого исследования — сеть отелей "Как в гостях".
# С целью привлечения клиентов, эта сеть отелей добавила на свой сайт возможность забронировать номер без предоплаты. Однако, если клиент отменял бронирование, то компания терпела убытки. Сотрудники отеля могли, например, закупить продукты к приезду гостя или просто не успеть найти другого клиента.
#
# **Цель проекта**
#
# Разработать систему, которая предсказывает отказ от брони. Если модель покажет, что бронь будет отменена, то клиенту предлагается внести депозит. Размер депозита — 80% от стоимости номера за одни сутки и затрат на разовую уборку. Деньги будут списаны со счёта клиента, если он всё же отменит бронь.
#
# **Бизнес-метрика и другие данные**
#
# Основная бизнес-метрика для любой сети отелей — её прибыль. Прибыль отеля — это разница между стоимостью номера за все ночи и затраты на обслуживание: как при подготовке номера, так и при проживании постояльца. В отеле есть несколько типов номеров. В зависимости от типа номера назначается стоимость за одну ночь. Есть также затраты на уборку. Если клиент снял номер надолго, то убираются каждые два дня.
#
#
# Стоимость номеров отеля:
#
# - категория A: за ночь — 1 000, разовое обслуживание — 400;
# - категория B: за ночь — 800, разовое обслуживание — 350;
# - категория C: за ночь — 600, разовое обслуживание — 350;
# - категория D: за ночь — 550, разовое обслуживание — 150;
# - категория E: за ночь — 500, разовое обслуживание — 150;
# - категория F: за ночь — 450, разовое обслуживание — 150;
# - категория G: за ночь — 350, разовое обслуживание — 150.
#
# В ценовой политике отеля используются сезонные коэффициенты: весной и осенью цены повышаются на 20%, летом — на 40%. Убытки отеля в случае отмены брони номера — это стоимость одной уборки и одной ночи с учётом сезонного коэффициента. На разработку системы прогнозирования заложен бюджет — 400'000. При этом необходимо учесть, что внедрение модели должно окупиться за тестовый период. Затраты на разработку должны быть меньше той выручки, которую система принесёт компании.
#
# **Описание данных**
#
# В таблицах hotel_train и hotel_test содержатся одинаковые столбцы:
#
# - id — номер записи;
# - adults — количество взрослых постояльцев;
# - arrival_date_year — год заезда;
# - arrival_date_month — месяц заезда;
# - arrival_date_week_number — неделя заезда;
# - arrival_date_day_of_month — день заезда;
# - babies — количество младенцев;
# - booking_changes — количество изменений параметров заказа;
# - children — количество детей от 3 до 14 лет;
# - country — гражданство постояльца;
# - customer_type — тип заказчика:
#     - Contract — договор с юридическим лицом;
#     - Group — групповой заезд;
#     - Transient — не связано с договором или групповым заездом;
#     - Transient-party — не связано с договором или групповым заездом, но связано с бронированием типа Transient.
# - days_in_waiting_list — сколько дней заказ ожидал подтверждения;
# - distribution_channel — канал дистрибуции заказа;
# - is_canceled — отмена заказа;
# - is_repeated_guest — признак того, что гость бронирует номер второй раз;
# - lead_time — количество дней между датой бронирования и датой прибытия;
# - meal — опции заказа:
#     - SC — нет дополнительных опций;
#     - BB — включён завтрак;
#     - HB — включён завтрак и обед;
#     - FB — включён завтрак, обед и ужин.
# - previous_bookings_not_canceled — количество подтверждённых заказов у клиента;
# - previous_cancellations — количество отменённых заказов у клиента;
# - required_car_parking_spaces — необходимость места для автомобиля;
# - reserved_room_type — тип забронированной комнаты;
# - stays_in_weekend_nights — количество ночей в выходные дни;
# - stays_in_week_nights — количество ночей в будние дни;
# - total_nights — общее количество ночей;
# - total_of_special_requests — количество специальных отметок.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Отлично, что есть вступительный комментарий и содержание.

# %%
# !pip install imblearn
# Out:
# ...
#      |████████████████████████████████| 235 kB 2.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 301 kB 31.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 10.9 MB 59.1 MB/s eta 0:00:01
# ...
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.0
#     Uninstalling joblib-1.1.0:
#       Successfully uninstalled joblib-1.1.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.24.1
#     Uninstalling scikit-learn-0.24.1:
#       Successfully uninstalled scikit-learn-0.24.1
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from scipy import stats as st
import time

from sklearn.model_selection import RandomizedSearchCV, GridSearchCV, StratifiedKFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder, OrdinalEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.compose import ColumnTransformer
from sklearn.metrics import f1_score, roc_auc_score, accuracy_score, roc_curve, recall_score 
from sklearn.dummy import DummyClassifier
from imblearn.pipeline import Pipeline
from imblearn.pipeline import make_pipeline
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import NearMiss

import warnings

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
#
# <b>Все отлично!👍:</b>
#
# Отлично, что все импорты собраны в начале проекта. Это поможет в случае чего сразу увидеть, какие библиотеки следует доустановить.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# "Согласно руководству по написанию кода PEP8 все импорты должны располагаться сразу после комментариев к модулю и строк документации, но перед объявлением констант. При этом группировать их желательно в следующем порядке:
#
# импорты из стандартной библиотеки,
# импорты из сторонних библиотек,
# импорты пользовательских модулей текущего проекта."
#
# И между группами стоит оставлять пустую строку.
#
#
# Вот еще хорошая статья:
#
# https://okpython.net/python/python_uchebnik/osnovy/moduli_i_pakety_v_python.html
#
# Какие модули входят в стандартную библиотеку можно посмотреть вот здесь:
#
# https://docs.python.org/3/library/exceptions.html#warnings

# %%
warnings.filterwarnings('ignore')

# %%
# бюджет на разработку системы прогнозирования
BUDGET = 400_000

# размер депозита (коэффициент от стоимости и затрат)
DEPOSIT_SIZE = 0.8

# сезонные коэффициенты
SPRING_RATIO = 1.2
SUMMER_RATIO = 1.4
STANDART_RATIO = 1

# стоимость номеров за ночь
PRICE_CLASS_A = 1_000
PRICE_CLASS_B = 800
PRICE_CLASS_C = 600
PRICE_CLASS_D = 550
PRICE_CLASS_E = 500
PRICE_CLASS_F = 450
PRICE_CLASS_G = 350

# стоимость разового обслуживания
SERVICE_CLASS_A = 400
SERVICE_CLASS_B = 350
SERVICE_CLASS_C = 350
SERVICE_CLASS_D = 150
SERVICE_CLASS_E = 150
SERVICE_CLASS_F = 150
SERVICE_CLASS_G = 150

STATE = 12345

# %% [markdown]
# ### Шаг 1. Откройте файлы с данными

# %%
try:
    data_train = pd.read_csv('/datasets/hotel_train.csv')
    data_test = pd.read_csv('/datasets/hotel_test.csv')
except:
    print('Не удалось прочитать файл')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Отлично, что используешь конструкцию try/except для загрузки данных.

# %%
pd.set_option('display.max_columns', None)

# %%
data_train.head()
# Out:
#    id  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0   0            0        7.0               2015               July
# 1   1            0       14.0               2015               July
# 2   2            0        0.0               2015               July
# 3   3            0        9.0               2015               July
# 4   4            1       85.0               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     1     1.0       0.0     0.0
# ...

# %%
data_test.head()
# Out:
#      id  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  6086            1       74.0               2017            January
# 1  6087            1       62.0               2017            January
# 2  6088            1       62.0               2017            January
# 3  6089            1       71.0               2017            January
# 4  6090            1      172.0               2017            January
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                         1                          1
# 1                         1                          1
# 2                         1                          1
# 3                         1                          1
# 4                         1                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        1                     0     2.0       0.0     0.0
# ...

# %% [markdown]
# Файлы открыты и загружены. Перейдем к предобработке и ИАД.

# %% [markdown]
# ### Шаг 2. Предобработка и исследовательский анализ данных

# %% [markdown]
# #### Предобработка обучающей выборки

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65229 entries, 0 to 65228
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              65229 non-null  int64
#  1   is_canceled                     65229 non-null  int64
#  2   lead_time                       65229 non-null  float64
#  3   arrival_date_year               65229 non-null  int64
#  4   arrival_date_month              65229 non-null  object
#  5   arrival_date_week_number        65229 non-null  int64
#  6   arrival_date_day_of_month       65229 non-null  int64
#  7   stays_in_weekend_nights         65229 non-null  int64
#  8   stays_in_week_nights            65229 non-null  int64
#  9   adults                          65229 non-null  float64
#  10  children                        65229 non-null  float64
#  11  babies                          65229 non-null  float64
# ...

# %% [markdown]
# Выполним проверку на пропуски в данных.

# %%
pd.concat([data_train.isna().sum(), data_train.isna().mean().apply(lambda x: '{0:.1f}%'.format(x * 100))], 
          axis=1).rename(columns={0:'количество пропусков', 1:'доля пропусков'})
# Out:
#                                 количество пропусков доля пропусков
# id                                                 0           0.0%
# is_canceled                                        0           0.0%
# lead_time                                          0           0.0%
# arrival_date_year                                  0           0.0%
# arrival_date_month                                 0           0.0%
# arrival_date_week_number                           0           0.0%
# arrival_date_day_of_month                          0           0.0%
# stays_in_weekend_nights                            0           0.0%
# stays_in_week_nights                               0           0.0%
# adults                                             0           0.0%
# children                                           0           0.0%
# babies                                             0           0.0%
# meal                                               0           0.0%
# ...

# %% [markdown]
# Отлично, пропусков на обучающем наборе даных нет. Посомтрим на описательную статистику.

# %%
data_train.describe().T
# Out:
#                                   count          mean           std     min  \
# id                              65229.0  43544.069172  25614.858971     0.0
# is_canceled                     65229.0      0.368609      0.482431     0.0
# lead_time                       65229.0     96.337917     96.127545     0.0
# arrival_date_year               65229.0   2015.719021      0.449481  2015.0
# arrival_date_week_number        65229.0     31.339772     13.464024     1.0
# arrival_date_day_of_month       65229.0     15.847813      8.748182     1.0
# stays_in_weekend_nights         65229.0      0.825185      0.853477     0.0
# stays_in_week_nights            65229.0      2.224793      1.354992     0.0
# adults                          65229.0      1.836576      0.480245     0.0
# children                        65229.0      0.074890      0.334243     0.0
# babies                          65229.0      0.007236      0.098790     0.0
# ...

# %% [markdown]
# Анализируя данные можно сделать следующие наблюдения:
# - столбец ID не информативен и его можно убрать из анализа;
# - столбцы lead_time, adults, children и babies содержат количественные (целочисленные) данные, при этом тип данных определен как для вещественных чисел - правильным подходом будет изменить тип данных на целочисленный;
# - в столбце babies максимальное значение 10 - нужно взять на заметку.

# %%
# удалим лишний столбец
data_train.drop(['id'], axis='columns', inplace=True)

# приведем столбцы вещественного типа к целочисленному
lst = list(data_train.select_dtypes('float64').columns)
data_train[lst] = data_train[lst].astype('int64')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Молодец, что отбрасываешь столбец с id

# %% [markdown]
# Следующим шагом проверим наличие явных дубликатов.

# %%
print('Количество явных дубликатов равно', data_train.duplicated().sum())
print('Доля дубликатов составялет {0:.1f}%'.format(data_train.duplicated().sum() / data_train.shape[0] * 100))
# Out:
# Количество явных дубликатов равно 21377
# Доля дубликатов составялет 32.8%

# %% [markdown]
# Удаление дубликатов кажется не совсем правильным подходом, поэтому удалять дубликаты не будем.

# %% [markdown]
# **С обучающей выборкой поработали:**
# - пропусков в данных не вявлено;
# - удален столбец ID, который не информативен дл анализа;
# - заменены типы данных по столбцам, в которых это трубется;
# - устновлено количество явных дубликатов около 33% от всей выборке, удалять их не правильных подход, во-первых цифра 33% довольно большая и явно указывает на то, что дубликаты не случайны, во-вторых природа дубликатов не ясна и удаление их "в слепую" не самый удачный подход.

# %% [markdown]
# #### Предобработка тестовой выборки

# %%
data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32412 entries, 0 to 32411
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              32412 non-null  int64
#  1   is_canceled                     32412 non-null  int64
#  2   lead_time                       32412 non-null  float64
#  3   arrival_date_year               32412 non-null  int64
#  4   arrival_date_month              32412 non-null  object
#  5   arrival_date_week_number        32412 non-null  int64
#  6   arrival_date_day_of_month       32412 non-null  int64
#  7   stays_in_weekend_nights         32412 non-null  int64
#  8   stays_in_week_nights            32412 non-null  int64
#  9   adults                          32412 non-null  float64
#  10  children                        32412 non-null  float64
#  11  babies                          32412 non-null  float64
# ...

# %%
pd.concat([data_test.isna().sum(), data_test.isna().mean().apply(lambda x: '{0:.1f}%'.format(x * 100))], 
          axis=1).rename(columns={0:'количество пропусков', 1:'доля пропусков'})
# Out:
#                                 количество пропусков доля пропусков
# id                                                 0           0.0%
# is_canceled                                        0           0.0%
# lead_time                                          0           0.0%
# arrival_date_year                                  0           0.0%
# arrival_date_month                                 0           0.0%
# arrival_date_week_number                           0           0.0%
# arrival_date_day_of_month                          0           0.0%
# stays_in_weekend_nights                            0           0.0%
# stays_in_week_nights                               0           0.0%
# adults                                             0           0.0%
# children                                           0           0.0%
# babies                                             0           0.0%
# meal                                               0           0.0%
# ...

# %% [markdown]
# Отлично, пропусков на обучающем наборе даных нет. Посомтрим на описательную статистику.

# %%
data_test.describe().T
# Out:
#                                   count          mean           std     min  \
# id                              32412.0  60131.505183  29953.586177  6086.0
# is_canceled                     32412.0      0.388467      0.487409     0.0
# lead_time                       32412.0     97.587869     86.507146     0.0
# arrival_date_year               32412.0   2017.000000      0.000000  2017.0
# arrival_date_week_number        32412.0     17.804054      9.177384     1.0
# arrival_date_day_of_month       32412.0     15.656948      8.766429     1.0
# stays_in_weekend_nights         32412.0      0.867888      0.853394     0.0
# stays_in_week_nights            32412.0      2.340090      1.375170     0.0
# adults                          32412.0      1.858602      0.489341     0.0
# children                        32412.0      0.083765      0.343470     0.0
# babies                          32412.0      0.005523      0.075757     0.0
# ...

# %% [markdown]
# Анализируя данные можно сделать следующие наблюдения:
# - столбец ID не информативен и его можно убрать из анализа;
# - столбцы lead_time, adults, children и babies содержат количественные (целочисленные) данные, при этом тип данных определен как для вещественных чисел - правильным подходом будет изменить тип данных на целочисленный

# %%
# удалим лишний столбец
data_test.drop(['id'], axis='columns', inplace=True)

# приведем столбцы вещественного типа к целочисленному
lst = list(data_test.select_dtypes('float64').columns)
data_test[lst] = data_test[lst].astype('int64')

# %% [markdown]
# Следующим шагом проверим наличие явных дубликатов.

# %%
print('Количество явных дубликатов равно', data_test.duplicated().sum())
print('Доля дубликатов составялет {0:.1f}%'.format(data_test.duplicated().sum() / data_test.shape[0] * 100))
# Out:
# Количество явных дубликатов равно 7717
# Доля дубликатов составялет 23.8%

# %% [markdown]
# Удаление дубликатов кажется не совсем правильным подходом, поэтому удалять дубликаты не будем.

# %% [markdown]
# **С тестовой выборкой поработали, наблюдения аналоичные обучающей выборке:**
# - пропусков в данных не вявлено;
# - удален столбец ID, который не информативен дл анализа;
# - заменены типы данных по столбцам, в которых это трубется;
# - устновлено количество явных дубликатов около 24% от всей выборке, удалять их не правильных подход, во-первых цифра 24% довольно большая и явно указывает на то, что дубликаты не случайны, во-вторых природа дубликатов не ясна и удаление их "в слепую" не самый удачный подход.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Молодец, что изучаешь оба датафрейма

# %% [markdown]
# #### Исследование связи целевого признака с прочими

# %% [markdown]
# Для начала исследуем баланс классов

# %%
data_train['is_canceled'].value_counts(normalize=True)
# Out:
# 0    0.631391
# 1    0.368609
# Name: is_canceled, dtype: float64

# %% [markdown]
# Около 37% отменяют свои заказы. При работе с моделями необходимо будет учесть дисбаланс классов.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
#
# Отлично, что проводишь анализ баланса классов

# %% [markdown]
# Проверим наличие корреляции между целевым признаками.

# %%
fig = plt.figure(figsize=(8,10))
ax = sns.heatmap(
    data_train
    .corr()[['is_canceled']]
    .sort_values('is_canceled', ascending=False), 
    cmap="YlGnBu", annot=True)

ax.set_title('Коэффициент корреляции между признаками и статусом отмены бронирования', fontsize=14)
plt.show()

# %% [markdown]
# ~~Наблюдается не высокая корреляция между целевым признаком и lead_time (0.33), previous_cancellations (0.15). Также прослеживается отрицательная кореляция между целевым признаком и total_of_special_requests (-0.26), required_car_parking_spaces (-0.19) и booking_changes (-0.14)~~

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#
# Интерпертацию результатов корреляционного анализа стоит поправить, ниже таблица, которая может в этом помочь

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b> Комментарий студента: </b> Ниже под таблицей добавил праильные интерпретации

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Наблюдается слабая корреляция между целевым признаком и lead_time (0.33), c остальными признакми очень слабая (как полотижетльная? так и отрицательная для разных признаков)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера №2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# 1. Для расчета корреляций с учетом категориальных признаков стоит использовать инструменты, рассчитанные на это, например, https://phik.readthedocs.io/en/latest/
#
# 2. Коэффициент корреляции Пирсона (который по дефолту рассчитывается в методе corr), имеет определенные требования к данным:
#
# - характер взаимосвязи двух переменных должен быть линейным и монотонным (коэффициент корреляции Пирсона не может уловить нелинейные зависимости). Поэтому, чтобы проконтроллировать корректность применения коэффициента корреляции Пирсона стоит сначала построить диаграммы рассеяния для переменных.
#
# - распределения обоих переменных, для которых рассчитывается коэффициент должны быть распределены нормально. Также выбросы, ассиметрия, бимодальность негативно сказываются на адекватности использования среднего значения в качестве некоторого показателя, характеризующего нашу выборку (а коэффициент коррелиции Пирсона основан на среднем значении). Формулу можно посмотреть здесь:
#
# https://studfile.net/preview/2966946/page:34/
#
# Чтобы уменьшить негативное влияние выбросов можно перейти от коэффициента корреляции Пирсона к непараметрическому критерию корреляции - коэффициенту корреляции Спирмена, который уходит от реальных значенийи переходит к рангам.

# %% [markdown]
# Уберем лишние пробелы, если они присутствуют в данных.

# %%
list_name = ['country', 'arrival_date_month', 'meal' , 'distribution_channel', 'reserved_room_type', 'customer_type']
for i in list_name:
    data_train[i] = data_train[i].str.strip()
    data_test[i] = data_test[i].str.strip()

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Молодец, что работаешь со строковыми значенийми.

# %% [markdown]
# ##### Месяц заезда (arrival_date_month)

# %%
data_train.groupby('arrival_date_month')['is_canceled'].value_counts(normalize=True)
# Out:
# arrival_date_month  is_canceled
# April               0              0.607410
#                     1              0.392590
# August              0              0.611111
#                     1              0.388889
# December            0              0.651992
#                     1              0.348008
# February            0              0.648005
#                     1              0.351995
# January             0              0.742600
#                     1              0.257400
# July                0              0.611577
#                     1              0.388423
# June                0              0.585533
#                     1              0.414467
# March               0              0.692141
#                     1              0.307859
# May                 0              0.642292
#                     1              0.357708
# November            0              0.683388
#                     1              0.316612
# October             0              0.614695
# ...

# %% [markdown]
# В целом во все месяца года доля клиентов отменивших бронирование составляет около 30-40%, исключение январь - доля отмененных бронирований составила 26%.

# %% [markdown]
# ##### Опции заказа (meal)

# %%
data_train.groupby('meal')['is_canceled'].value_counts(normalize=True)
# Out:
# meal  is_canceled
# BB    0              0.633731
#       1              0.366269
# FB    1              0.689579
#       0              0.310421
# HB    0              0.614920
#       1              0.385080
# SC    0              0.656245
#       1              0.343755
# Name: is_canceled, dtype: float64

# %% [markdown]
# Ничего "особенного" не наблюдается, перекос в пользу клиентов не отказавшихся от бронирования в разрезе опций заказа примерно соответствует дисаблансу классов.

# %% [markdown]
# ##### Год заезда (arrival_date_year)

# %%
display(data_train.groupby('arrival_date_year')['is_canceled'].value_counts(normalize=True))
display(data_test.groupby('arrival_date_year')['is_canceled'].value_counts(normalize=True))
# Out:
# arrival_date_year  is_canceled
# 2015               0              0.607595
#                    1              0.392405
# 2016               0              0.640690
#                    1              0.359310
# Name: is_canceled, dtype: float64
# arrival_date_year  is_canceled
# 2017               0              0.611533
#                    1              0.388467
# Name: is_canceled, dtype: float64

# %% [markdown]
# Года в тестовой и обучающей выборках различны, при этом доля отменивших заказы примерно одинакова во всех годах. Удалим этот столбец из анализа.

# %%
data_train.drop(['arrival_date_year'], axis='columns', inplace=True)
data_test.drop(['arrival_date_year'], axis='columns', inplace=True)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Молодец, что принимаешь этот факт во внимание.

# %% [markdown]
# ##### Количество дней между датой бронирования и датой прибытия (lead_time)

# %%
sns.set_style("white")
fig, ax = plt.subplots(figsize=(18,6))

sns.histplot(data=data_train, x='lead_time',hue='is_canceled', kde=True, bins=50, edgecolor='black', ax=ax)
plt.title('Распределение бронирования номеров', fontsize='14')
plt.xlabel('Количество дней между датой бронирования и датой прибытия/ отмены', fontsize='12')
plt.ylabel('Колличество заказов', fontsize='12')
plt.show()


fig, ax = plt.subplots(figsize=(18,6))
sns.boxplot(data=data_train, x='is_canceled',y='lead_time', ax=ax)
plt.title('Даиграмма размаха количества дней между датой бронирования и датой прибытия/ отмены', fontsize='14')
plt.xlabel('Факт отмены бронирования: 0 - клиент остался, 1 - отказ от брони', fontsize='12')
plt.ylabel('Количество дней', fontsize='12')
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Хорошие графики, молодец!

# %% [markdown]
# Проверим гипотезу о равенстве средний в двух группах

# %%
# Гипотезу о равенстве средних значений между классами будем проверять с помощью T-test 
# Создадим простую функцию, к которой будем обращаться в дальнейшем
# Параметр equal_var укажем как False, учитывая, что мы не можем однозначно сказать, что дисперсии выборок равны, 
# а также мы знаем о дисбалансе выборок (выборки не равны между собой)

def get_ttest_value (data, target):
    results = st.ttest_ind(
    data[data['is_canceled'] == 0][target],
    data[data['is_canceled'] == 1][target],
    equal_var = False)

    alpha = 0.05

    print(results.pvalue)

    if (results.pvalue < alpha):
        print("Отвергаем нулевую гипотезу")
    else:
        print("Не получилось отвергнуть нулевую гипотезу")

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Отлично, что оптимизируешь свой код с помощью пользовательских функций.

# %%
get_ttest_value(data_train, 'lead_time')
# Out:
# 0.0
# Отвергаем нулевую гипотезу

# %% [markdown]
# Гипотеза о равенстве среднего количества дней между датой бронирования и датой прибытия в двух группа не подтвредилась, что говорит о влиянии этого фактора на факт отмены бронирования. В целом на диаграмме размаха видно, что для клиентов не отменивших бронирования есть редкие знаечния (выбивающтеся за границы усов) свыше 250 дней, а для клиентов отменивших такие значения норма. Медианы в группах также различны, для не отменивших клиентов около 50 дней, а для отменишвих около 100. Соответственно, наблюдение следующее - чем длинее срок между броинрования от даты заезда, тем выше вероятность отказа от брони.

# %% [markdown]
# ##### Неделя заезда (arrival_date_week_number)

# %%
sns.set_style("white")
fig, ax = plt.subplots(figsize=(18,6))

sns.histplot(data=data_train, x='arrival_date_week_number', hue='is_canceled', kde=True, bins=60, edgecolor='black', ax=ax)
plt.title('Распределение недель заезда', fontsize='14')
plt.xlabel('Неделя года', fontsize='12')
plt.ylabel('Колличество заказов', fontsize='12')
plt.show()


fig, ax = plt.subplots(figsize=(18,6))
sns.boxplot(data=data_train, x='is_canceled',y='arrival_date_week_number', ax=ax)
plt.title('Диаграмма размаха', fontsize='14')
plt.xlabel('Факт отмены бронирования: 0 - клиент остался, 1 - отказ от брони', fontsize='12')
plt.ylabel('День месяца', fontsize='12')
plt.show()

# %% [markdown]
# Чаще вего бронируют с 38 по 50 неделю. Визуально средние величины равны в друх группах. Проверим гипотезу о равенстве.

# %%
get_ttest_value(data_train, 'arrival_date_week_number')
# Out:
# 0.0008027570438809509
# Отвергаем нулевую гипотезу

# %% [markdown]
# Не смотря на визуально очень близкие средние величины и медианы, гипотеза не подтвредилась, что может свидельствовать о начилии зависимости между неделей заезда и фактом отмены броинрования. Выбросов не наблюдается.

# %% [markdown]
# ##### День заезда (arrival_date_day_of_month)

# %%
sns.set_style("white")
fig, ax = plt.subplots(figsize=(18,6))

sns.histplot(data=data_train, x='arrival_date_day_of_month',hue='is_canceled', kde=True, bins=30, edgecolor='black', ax=ax)
plt.title('Распределение дней заезда', fontsize='14')
plt.xlabel('День месяца', fontsize='12')
plt.ylabel('Колличество заказов', fontsize='12')
plt.show()


fig, ax = plt.subplots(figsize=(18,6))
sns.boxplot(data=data_train, x='is_canceled',y='arrival_date_day_of_month', ax=ax)
plt.title('Диаграмма размаха', fontsize='14')
plt.xlabel('Факт отмены бронирования: 0 - клиент остался, 1 - отказ от брони', fontsize='12')
plt.ylabel('День месяца', fontsize='12')
plt.show()

# %% [markdown]
# Визуально можно выдвинуть пердположение, что в среднем день заезда одинаковый дял двух групп. Проверим эту гипотезу.

# %%
get_ttest_value(data_train, 'arrival_date_day_of_month')
# Out:
# 0.6268222228904005
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# Получается день заезда не особо влияет на вероятность отказа от бронирования, темне-менее не линейная связь вместе с другим признаком может повлиять на конечный результат, поэтому не будем удалять этот признак из анализа.

# %% [markdown]
#  ##### Количество ночей в выходные дни (stays_in_weekend_nights)

# %%
sns.set_style("white")
fig, ax = plt.subplots(figsize=(18,6))

sns.histplot(data=data_train, x='stays_in_weekend_nights',hue='is_canceled', kde=True, bins=20, edgecolor='black', ax=ax)
plt.title('Распределение бронирования ночей в выходные дни', fontsize='14')
plt.xlabel('Количество бронируемых ночей', fontsize='12')
plt.ylabel('Колличество заказов', fontsize='12')
plt.show()


fig, ax = plt.subplots(figsize=(18,6))
sns.boxplot(data=data_train, x='is_canceled',y='stays_in_weekend_nights', ax=ax)
plt.title('Даиграмма размаха', fontsize='14')
plt.xlabel('Факт отмены бронирования: 0 - клиент остался, 1 - отказ от брони', fontsize='12')
plt.ylabel('Количество ночей', fontsize='12')
plt.show()

# %% [markdown]
# Распредления и ящики с усами очень похожу в двух группах. Проверим гипотезу о равенстве среднего количества бронируемых ночей в выходные дни.

# %%
get_ttest_value(data_train, 'stays_in_weekend_nights')
# Out:
# 0.0004331548134290727
# Отвергаем нулевую гипотезу

# %% [markdown]
# Получается, что в среднем количество ночей бронирования в выходные дни в двух группах различно, а соответственно влияет на вероятность отмены/ не отмены бронирования. Не свосем понятно, что означает 0 при бронировании - 1 ночь или на день. Лучше уточнить у заказчика.

# %% [markdown]
# ##### Количество ночей в будние дни (stays_in_week_nights)

# %%
sns.set_style("white")
fig, ax = plt.subplots(figsize=(18,6))
sns.histplot(data=data_train, x='stays_in_week_nights',hue='is_canceled', kde=True, bins=20, edgecolor='black', ax=ax)
plt.title('Распределение бронирования ночей в будние дни', fontsize='14')
plt.xlabel('Количество бронируемых ночей', fontsize='12')
plt.ylabel('Колличество заказов', fontsize='12')
plt.show()


fig, ax = plt.subplots(figsize=(18,6))
sns.boxplot(data=data_train, x='is_canceled',y='stays_in_week_nights', ax=ax)
plt.title('Даиграмма размаха', fontsize='14')
plt.xlabel('Факт отмены бронирования: 0 - клиент остался, 1 - отказ от брони', fontsize='12')
plt.ylabel('Количество ночей', fontsize='12')
plt.show()

# %% [markdown]
# Распредления и ящики с усами очень похожу в двух группах. Проверим гипотезу о равенстве среднего количества бронируемых ночей в будние дни.

# %%
get_ttest_value(data_train, 'stays_in_week_nights')
# Out:
# 0.005379872084138059
# Отвергаем нулевую гипотезу

# %% [markdown]
# Получается, что в среднем количество ночей бронирования в будние дни в двух группах различно, а соответственно влияет на вероятность отмены/ не отмены бронирования. В целом хорошо проглядывается перекос в пользу клиентов отменяющих бронь при бронировании 2 ночей, в остальных случаях соотношение +/- одинаковое. Не свосем понятно, что означает 0 при бронировании - 1 ночь или на день. лУчше уточнить у заказчика.

# %% [markdown]
# ##### Количество взрослых постояльцев (adults)

# %%
data_train.groupby('adults')['is_canceled'].value_counts(normalize=True)
# Out:
# adults  is_canceled
# 0       0              0.710843
#         1              0.289157
# 1       0              0.695883
#         1              0.304117
# 2       0              0.609800
#         1              0.390200
# 3       0              0.697341
#         1              0.302659
# 4       0              0.923077
#         1              0.076923
# Name: is_canceled, dtype: float64

# %%
sns.catplot(data=data_train, 
            x='adults', 
            hue='is_canceled', 
            kind = 'count',  edgecolor='black', height=6, aspect=2)
plt.title('Распределение клиентов по количеству детей', fontsize='14')
plt.xlabel('Количество детей (от 3до 14 лет)', fontsize='12')
plt.ylabel('Количество', fontsize='12')
plt.show()

# %% [markdown]
# Ничего "особенного" не наблюдается, перекос в пользу клиентов не отказавшихся от бронирования в разрезе по количеству взрослых постояльцев примерно соответствует дисаблансу классов. Интересное наблюдение в отсутствии взрослых постольцев - нужно уточнить у заказчика, что означает 0.

# %% [markdown]
# ##### Количество детей от 3 до 14 лет (children)

# %%
data_train.groupby('children')['is_canceled'].value_counts(normalize=True)
# Out:
# children  is_canceled
# 0         0              0.628435
#           1              0.371565
# 1         0              0.713626
#           1              0.286374
# 2         0              0.634731
#           1              0.365269
# 3         0              0.625000
#           1              0.375000
# Name: is_canceled, dtype: float64

# %%
sns.catplot(data=data_train, 
            x='children', 
            hue='is_canceled', 
            kind = 'count',  edgecolor='black', height=6, aspect=2)
plt.title('Распределение клиентов по количеству детей', fontsize='14')
plt.xlabel('Количество детей (от 3до 14 лет)', fontsize='12')
plt.ylabel('Количество', fontsize='12')
plt.show()

# %% [markdown]
# Аналогично признаку "Количество взрослых постояльцев" ничего "особенного" не наблюдается, перекос в пользу клиентов не отказавшихся от бронирования в разрезе колиечества детей +/- соответствует дисаблансу классов.

# %% [markdown]
# ##### Количество младенцев (babies)

# %%
data_train.groupby('babies')['is_canceled'].value_counts(normalize=True)
# Out:
# babies  is_canceled
# 0       0              0.630085
#         1              0.369915
# 1       0              0.816555
#         1              0.183445
# 2       0              1.000000
# 9       0              1.000000
# 10      0              1.000000
# Name: is_canceled, dtype: float64

# %% [markdown]
# Вспоминаем наблюдение на этапе предобработки - 9-10 младенцев. Явная "аномалия", скорее всего данные занесены не корректно. Удалим эти данные.

# %%
data_train = data_train.drop(data_train.query('babies > 3').index)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Молодец, что отбрасываешь аномальные значения.

# %%
sns.catplot(data=data_train, 
            x='babies', 
            hue='is_canceled', 
            kind = 'count',  edgecolor='black', height=6, aspect=2)
plt.title('Распределение клиентов по количеству младенцев', fontsize='14')
plt.xlabel('Количество младенцев', fontsize='12')
plt.ylabel('Количество', fontsize='12')
plt.show()

# %% [markdown]
# Анализируя данные можно придти к следующим наблюдениям:
# - клиенты у которых 1 младенец и более чаще не отказываются от брони, однако сделать однзначное утверждение нельзя, т.к. данных не достаточно;
# - клиенты у которых нет младенцев также чаще не отказываются от брони (около 63%) и снова выходим на примерно соотношение дисбаланса классов.

# %% [markdown]
# ##### Повтроный клиент или нет (is_repeated_guest)

# %%
data_train.groupby('is_repeated_guest')['is_canceled'].value_counts(normalize=True)
# Out:
# is_repeated_guest  is_canceled
# 0                  0              0.628136
#                    1              0.371864
# 1                  0              0.747600
#                    1              0.252400
# Name: is_canceled, dtype: float64

# %%
sns.catplot(data=data_train, 
            y='is_repeated_guest', 
            hue='is_canceled', 
            kind = 'count',  edgecolor='black', height=6, aspect=2)
plt.title('Распределение повторныных/ новых клиентов', fontsize='14')
plt.xlabel('Количество', fontsize='12')
plt.ylabel('Повтороный клиент: 0 - новый, 1 - повторный', fontsize='12')
plt.show()

# %% [markdown]
# Исходя из данных обучающей выборки можно предположить, что если клиент повторный то вероятность отмены бронирования ниже, однако таких клиентво очень мало и сделать однозначный вывод нельзя. Никаких явных особенностей у этого признака нет.

# %% [markdown]
# ##### Количество отменённых заказов у клиента (previous_cancellations)

# %%
sns.set_style("white")

fig, ax = plt.subplots(figsize=(18,6))
sns.histplot(data=data_train, x='previous_cancellations', 
             hue='is_canceled', bins = 40,  edgecolor='black', ax=ax)
plt.title('Распределение количества отменённых заказаов', fontsize='14')
plt.xlabel('Количество', fontsize='12')
plt.ylabel('Колличество заказов', fontsize='12')
plt.show()

fig, ax = plt.subplots(figsize=(18,6))
sns.boxplot(data=data_train, x='is_canceled', y='previous_cancellations', ax=ax)
plt.title('Диаграмма количества отменённых заказаов', fontsize='14')
plt.xlabel('Факт отмены бронирования: 0 - клиент остался, 1 - отказ от брони', fontsize='12')
plt.ylabel('Количество', fontsize='12')
plt.show()

# %% [markdown]
# Анализируя дигараммы выше можно сделать одназначный вывод, что в основном клиенты не имеют отмененных заказов - ярко выраженный пик на диаграмме распредления количества отмененных заказов. При этом малая часть клиентов все-же имеет некоторую историю, но эти клиенты лежат за границами "усов" диаграммы размаха. Удалять данные не будем, так как модель должна учиться работать с разными данными.

# %% [markdown]
# ##### Количество подтверждённых заказов у клиента (previous_bookings_not_canceled)

# %%
sns.set_style("white")

fig, ax = plt.subplots(figsize=(18,6))
sns.histplot(data=data_train, x='previous_bookings_not_canceled', 
             hue='is_canceled', kde = True, bins = 100,  edgecolor='black', ax=ax)
plt.title('Распределение количества подтврежденных заказаов', fontsize='14')
plt.xlabel('Количество', fontsize='12')
plt.ylabel('Колличество заказов', fontsize='12')
plt.show()

fig, ax = plt.subplots(figsize=(18,6))
sns.boxplot(data=data_train, x='is_canceled', y='previous_bookings_not_canceled', ax=ax)
plt.title('Диаграмма количества подтврежденных заказаов', fontsize='14')
plt.xlabel('Факт отмены бронирования: 0 - клиент остался, 1 - отказ от брони', fontsize='12')
plt.ylabel('Количество', fontsize='12')
plt.show()

# %% [markdown]
# Анализируя дигараммы выше формируюется следующее наблюдение - в основном клиенты не имеют подвтержденных заказов, что хорошо видно на гистограмме - ярко выраженный пик. При этом малая часть клиентов все-же имеет некоторую историю, но эти клиенты лежат за границами "усов" диаграммы размаха.Удалять данные не будем, так как модель должна учиться работать с разными данными.

# %% [markdown]
# ##### Количество изменений параметров заказа (booking_changes)

# %%
sns.set_style("white")

fig, ax = plt.subplots(figsize=(18,6))
sns.histplot(data=data_train, x='booking_changes', hue='is_canceled', bins = 50,  edgecolor='black', ax=ax)
plt.title('Распределение количества итераций изменения параметров бронирования', fontsize='14')
plt.xlabel('Количество', fontsize='12')
plt.ylabel('Колличество заказов', fontsize='12')
plt.show()


fig, ax = plt.subplots(figsize=(18,6))
sns.boxplot(data=data_train, x='is_canceled',y='booking_changes', ax=ax)
plt.title('Даиграмма количества итераций изменения параметров бронирования', fontsize='14')
plt.xlabel('Факт отмены бронирования: 0 - клиент остался, 1 - отказ от брони', fontsize='12')
plt.ylabel('Количество', fontsize='12')
plt.show()

# %% [markdown]
# В основном клиенты (как отменившие, так и нет) не вносят изменений в бронь, что хорошо видно на графиках выше. Есть крайне редкие значения, но они яялются "выбросами" (лежащими за гарницами усов), но мы приняли подход не удалять такие данные, модель должна учиться работать с разными данными.

# %% [markdown]
# ##### Количество дней ожидания подтвреждения (days_in_waiting_list)

# %% [markdown]
# Построим гистраграмму и диаграмму размаха.

# %%
sns.set_style("white")
fig, ax = plt.subplots(figsize=(18,6))

sns.histplot(data=data_train, x='days_in_waiting_list', hue='is_canceled', bins = 20,  edgecolor='black', ax=ax)
plt.title('Распределение количества дней ожидания подтвреждения брони', fontsize='14')
plt.xlabel('Количество дней', fontsize='12')
plt.ylabel('Колличество заказов', fontsize='12')
plt.show()


fig, ax = plt.subplots(figsize=(18,6))
sns.boxplot(data=data_train, x='is_canceled',y='days_in_waiting_list', ax=ax)
plt.title('Даиграмма количества дней ожидания подтвреждения брони', fontsize='14')
plt.xlabel('Факт отмены бронирования: 0 - клиент остался, 1 - отказ от брони', fontsize='12')
plt.ylabel('Количество дней', fontsize='12')
plt.show()

# %% [markdown]
# Анализируя графики выше можно сделать следующие выводы:
# - в основном заказаы подтвреждались моментально;
# - есть заказы которые подвтрежадилсь до 250 дней - природа таких "долгих" подвтреждений не ясна, поэтому удалять "в слепую" эти данные будет не правильно, возможно, стоит уточнить у заказчика и при необходимости вернуться к исследованию.

# %% [markdown]
# ##### Необходимость места для автомобиля (required_car_parking_spaces)

# %%
data_train.groupby('required_car_parking_spaces')['is_canceled'].value_counts(normalize=True)
# Out:
# required_car_parking_spaces  is_canceled
# 0                            0              0.609327
#                              1              0.390673
# 1                            0              1.000000
# 2                            0              1.000000
# 3                            0              1.000000
# Name: is_canceled, dtype: float64

# %%
sns.set_style("white")

fig, ax = plt.subplots(figsize=(18,6))
sns.boxplot(data=data_train, x='is_canceled',y='required_car_parking_spaces', ax=ax)
plt.title('Даиграмма размаха количества парковочных мест', fontsize='14')
plt.xlabel('Факт отмены бронирования: 0 - клиент остался, 1 - отказ от брони', fontsize='12')
plt.ylabel('Количество', fontsize='12')
plt.show()

# %% [markdown]
# Исходя из данных на обучающей выборке можно сделать следующие наблюдения:
# - если клиент указывает, на необходимость машиноместа, то вероятнее всего он не отказывается от бронирования;
# - в основной массе клиентам не требуется парковочные места;
# - аномалий в данных нет, только редкие значения, котоыре отличаются от основной массы, но удалять их не будем.

# %% [markdown]
# ##### Количество специальных отметок (total_of_special_requests)

# %% [markdown]
# Исходя из условий задачи не совесм понятно, что такое "количество специальных отметок", темне менее посмотрим на данные и поробуем сделать выводы.

# %%
data_train.groupby('total_of_special_requests')['is_canceled'].value_counts(normalize=True)
# Out:
# total_of_special_requests  is_canceled
# 0                          0              0.520507
#                            1              0.479493
# 1                          0              0.818718
#                            1              0.181282
# 2                          0              0.805556
#                            1              0.194444
# 3                          0              0.804054
#                            1              0.195946
# 4                          0              0.878505
#                            1              0.121495
# 5                          0              1.000000
# Name: is_canceled, dtype: float64

# %% [markdown]
# При отсутсвтии специальных отметок вероятнось отказа от брони примерно одинаковое. Чем больше количество отметок, тем выше вероятность того, что клиент не откажется от брони. Построим диаграмму размаха:

# %%
sns.set_style("white")

fig, ax = plt.subplots(figsize=(18,6))
sns.boxplot(data=data_train, x='is_canceled',y='total_of_special_requests', ax=ax)
plt.title('Даиграмма размаха количества специальных отметок', fontsize='14')
plt.xlabel('Факт отмены бронирования: 0 - клиент остался, 1 - отказ от брони', fontsize='12')
plt.ylabel('Количество', fontsize='12')
plt.show()

# %% [markdown]
# Аномальных значений (например, 30 отметок) не наблюдается. В основном клиенты оставляют не более 2 отметок, 3,4,5 - намного реже.

# %% [markdown]
# ##### Общее количество ночей (total_nights)

# %% [markdown]
# Построим диаграмму разамаха для общего количества забронированных ночей в отеле.

# %%
sns.set_style("white")

fig, ax = plt.subplots(figsize=(18,6))
sns.boxplot(data=data_train, x='is_canceled',y='total_nights', ax=ax)
plt.title('Даиграмма размаха количества ночей бронирования', fontsize='14')
plt.xlabel('Факт отмены бронирования: 0 - клиент остался, 1 - отказ от брони', fontsize='12')
plt.ylabel('Количество', fontsize='12')
plt.show()

# %% [markdown]
# В целом аномалий (например, 90 ночей) нет. В каждой группе есть редкие значения, но вес-такие это не аномалиии, а следовательно удалять их не будем. Судя по визуализации можно предположить, что в среднем количесто бронируемых ночей одинакое в двух группах. Проверим это гипотезу.

# %%
get_ttest_value(data_train, 'total_nights')
# Out:
# 0.688227940071217
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# Не получилось отвергнуть нулевую гипотезу, а следовательно общее количество бронируемых ночей особо не влияет на факт отказа от брони. Однако не линейная связь с дургим признакми может пристутстововать, удалтья тот признак из анализа не будем.

# %% [markdown]
# #### Вывод по результатам предобработки и исследования целевого признака
#
# **Для обучающей и тестовой выборок проведена предобработка данных**
# - пропусков в данных не выявлено;
# - устновлено количество явных дубликатов более 20% от каждой из выборок, удалять их не правильных подход, во-первых цифра довольно большая и явно указывает на то, что дубликаты не случайны, во-вторых природа дубликатов не ясна и удаление их "в слепую" не самый удачный подход.
#
# **Проведен исследовательский анализ целевого признака с прочими на обучающей выборке**
# - исследован дисбаланс классов, соотношение 63% (не отменившие заказ) на 37% (отменившие заказ), дисабаласн нужно учесть при обучении модели;
# - по результатам исследования связи целевого признака с другими были установлены признаки котоыре влияют в большей степени (в т.ч. по результатам статистичесих тестов), так и не влияющие, темне-менее возможны не линейне зависимости с другими признаками;
# - в данных присутствуют выбросы (редкие значения), однако удалять их не будем, модель должна учиться работать с разными данными.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Молодец, что проводишь подробный, равернутый EDA с точки зрения отмены брони

# %% [markdown]
# ### Шаг 3. Формулировка ML-задачи на основе бизнес-задачи

# %% [markdown]
# Оценим прибыль отеля без внедрения депозитов. Напишем функцию season_ratio, которая рассчитает сезонный коэффициент, 20% для осени, 40% летом и для остальных сезонов он равен 1. А также функцию price_service_room для расчёта стоимости номера и стоимости разового обслуживания.

# %%
def season_ratio(months):

    season_rates = months.copy()
    season_rates.loc[(months == 'June') | (months == 'July') | (months == 'August')] = SUMMER_RATIO
    
    season_rates.loc[(months == 'September') | (months == 'October') | (months == 'November') |
                     (months == 'March') | (months == 'April') | (months == 'May')] = SPRING_RATIO
    
    season_rates.loc[(months == 'December') | (months == 'January') | (months == 'February')] = STANDART_RATIO

    return season_rates

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#
# Проверь, пожалуйста, присвоение коэффициентов месяцам

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b> Комментарий студента: </b> Действительно напутал

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера №2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>

# %%
def price_service_room(room_type):

    prices = room_type.copy()
    services = room_type.copy()

    # присвоим стоимость номера
    prices.loc[room_type == 'A'] = PRICE_CLASS_A
    prices.loc[room_type == 'B'] = PRICE_CLASS_B
    prices.loc[room_type == 'C'] = PRICE_CLASS_C
    prices.loc[room_type == 'D'] = PRICE_CLASS_D
    prices.loc[room_type == 'E'] = PRICE_CLASS_E
    prices.loc[room_type == 'F'] = PRICE_CLASS_F
    prices.loc[room_type == 'G'] = PRICE_CLASS_G

    # присвоим стоимость разового обслуживания
    services.loc[room_type == 'A'] = SERVICE_CLASS_A
    services.loc[room_type == 'B'] = SERVICE_CLASS_B
    services.loc[room_type == 'C'] = SERVICE_CLASS_C
    services.loc[room_type == 'D'] = SERVICE_CLASS_D
    services.loc[room_type == 'E'] = SERVICE_CLASS_E
    services.loc[room_type == 'F'] = SERVICE_CLASS_F
    services.loc[room_type == 'G'] = SERVICE_CLASS_G

    return prices, services

# %% [markdown]
# Определеим сезонные коэффициенты для тестово выборки, стоимость номера и стоимость разового обслуживания.

# %%
season_rates = season_ratio(data_test['arrival_date_month'])
room_price, services = price_service_room(data_test['reserved_room_type'])
total_nights = data_test['total_nights']

# %% [markdown]
# Рассчитаем прибыль отеля или убыток, в случае отмены бронирования. Так как уборка производится каждые два дня, разделим пополам и округлим в большую сторону количество ночей.

# %%
profit = data_test['arrival_date_month'].copy()

profit.loc[data_test['is_canceled'] == 0] = \
    room_price * season_rates * total_nights - services * np.ceil(total_nights / 2)

profit.loc[data_test['is_canceled'] == 1] = - (room_price * season_rates + services)

# %% [markdown]
# Вычислим прибыль и убытки отеля без учёта внедрения депозитов.

# %%
profit_total = profit.sum()
loss_total = profit.loc[data_test['is_canceled'] == 1].sum()

print(f"Прибыль отелея без внедрения депозитов: {profit_total:,} руб.")
print(f"Убытки отеля при отмене брони: {loss_total:,} руб.")
print(f"Убытки составляют {-1 * loss_total / profit_total:.1%} от прибыли.")
# Out:
# Прибыль отелея без внедрения депозитов: 35,300,770.0 руб.
# Убытки отеля при отмене брони: -18,041,560.0 руб.
# Убытки составляют 51.1% от прибыли.

# %% [markdown]
# **По результатам данного шага**:
# - оценена прибыль отеля без вндрения депозитов - 35,3 млн руб.;
# - дополнительно проанализированы убытки отеля при отмене бронирования и результаты весьма не утешительные, убытки составли более 50% от прибыли.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Расчет прибыли проведен корректно, молодец!

# %% [markdown]
# ### Шаг 4. Разработка модели ML

# %% [markdown]
# Перейдем к обучению моделей. Первым шагом определим столбцы с каттегориальными переменными и численными - необходимо для корректного кодирования и масштабирования.

# %%
num_columns_list = ['lead_time', 'stays_in_weekend_nights', 'stays_in_week_nights', 'previous_cancellations',
                    'previous_bookings_not_canceled', 'booking_changes', 'days_in_waiting_list',
                    'total_of_special_requests', 'total_nights']

cat_columns_list = ['arrival_date_month', 'arrival_date_week_number',
                    'arrival_date_day_of_month', 'adults', 'children', 'babies', 'meal',
                    'country', 'distribution_channel', 'is_repeated_guest', 'reserved_room_type',
                    'customer_type',  'required_car_parking_spaces']

# %% [markdown]
# Подготовим данные и набор параметров для моделей.

# %%
# создадим признаки для моделей
features_train = data_train.drop('is_canceled', axis=1)
features_test = data_test.drop('is_canceled', axis=1)

# выделим целевой признак
target_train = data_train['is_canceled']
target_test = data_test['is_canceled']

# зададим диапазоны гиперпараметров для подбора
#param_distributions_rfc = {
#                       'RFC__n_estimators': range(1, 100, 1),
#                       'RFC__max_depth': range(1, 50, 1),
#                       'RFC__min_samples_split': range(2, 52, 1),
#                       'RFC__min_samples_leaf': range(2, 52, 1),
#                       'RFC__criterion':['gini','entropy']}


param_distributions_rfc = {'RFC__n_estimators': range(50, 325, 25),
                       'RFC__max_depth': range(1, 18, 1),
                       'RFC__min_samples_split': range(2, 52, 5),
                       'RFC__min_samples_leaf': range(2, 52, 5)}
param_distributions_lr = {
                       'LR__penalty':['l1','l2'],
                       'LR__C': np.arange(0.1,5, 0.1)}

# подготовим кросс-валидацию на 5 выборках
kf = StratifiedKFold(n_splits=3, shuffle=True, random_state=STATE)

# %% [markdown]
# Для обучения выберем метрику recall (полнота), потому что эта метрика показывает, какую долю объектов положительного класса из всех объектов положительного класса нашел алгоритм. Для снижения затрат нам как раз важно найти наибольшее количество тех, кто отменит бронирование и предложить им внести депозит.
#
# Обучим модели с использованием различных методов масштабирования, кодирования категориальных признаков и баланасировки классов.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
#
# Отлично, что есть обоснование выбора метрики.

# %% [markdown]
# #### Случайный лес с балансировкой весов c применением техники OHE и StandardScaler для кодирования и масштабирования данных

# %%
FPP = ('FPP', ColumnTransformer([
        ('num_features', make_pipeline(StandardScaler()), num_columns_list),
        ('cat_features', make_pipeline(OneHotEncoder(sparse=False, handle_unknown='ignore')), cat_columns_list)]))
RFC = ('RFC', RandomForestClassifier(random_state=STATE, class_weight='balanced'))

# зададим последовательность обработки
pipeline_RFC = Pipeline(steps=[FPP, RFC])

rs_rfc_ohe_ss = RandomizedSearchCV(
    pipeline_RFC, 
    param_distributions_rfc, 
    n_iter=100, 
    cv=kf, 
    verbose=1,
    n_jobs=-1, 
    scoring='recall', 
    return_train_score=True, 
    random_state=STATE)

start_time = time.time()
rs_rfc_ohe_ss.fit(features_train, target_train)
run_time = (time.time() - start_time) / 60

print(f'recall = {rs_rfc_ohe_ss.best_score_:.4f}')
df_results = pd.DataFrame({'Модель': ['Random Forest + OHE + Standart Scaler'], 
                           'recall': [rs_rfc_ohe_ss.best_score_],
                           'Время обучения (минуты)': [run_time], 
                           'Гиперпараметры': [rs_rfc_ohe_ss.best_params_]})
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Отлично, что обучение проводишь с учетом дисбаланса классов.
#
# Отлично, что качество исследуешь на кросс-валидации, а также подбираешь оптимальные значения гиперпараметров.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# У OneHotEncoder можно задать параметр *drop=first*, чтобы учесть проблему мультиколлинеарности.
#
# Чтобы этот параметр работал вместе с *handle_unknown* достаточно обновить версию sklearn
#
# *!pip install scikit-learn==1.1.3*
#
# Важно сделать это до импорта кодера.

# %% [markdown]
# #### Случайный лес с балансировкой весов c применением техники OrdinalEncoder и MinMaxScaler для кодирования и масштабирования данных

# %%
FPP = ('FPP', ColumnTransformer([
        ('num_features', make_pipeline(MinMaxScaler()), num_columns_list),
        ('cat_features', make_pipeline(OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)), cat_columns_list)]))

RFC = ('RFC', RandomForestClassifier(random_state=STATE, class_weight='balanced'))

# зададим последовательность обработки
pipeline_RFC = Pipeline(steps=[FPP, RFC])

rs_rfc_mms_oe = RandomizedSearchCV(
    pipeline_RFC, 
    param_distributions_rfc, 
    n_iter=100, 
    cv=kf, 
    verbose=1,
    n_jobs=-1, 
    scoring='recall', 
    return_train_score=True, 
    random_state=STATE)

start_time = time.time()
rs_rfc_mms_oe.fit(features_train, target_train)
run_time = (time.time() - start_time) / 60

print(f'recall = {rs_rfc_mms_oe.best_score_:.4f}')

df_results.loc[len(df_results.index)] = ['Random Forest + OE + Min Max Scaler',
                                         rs_rfc_mms_oe.best_score_, run_time, rs_rfc_mms_oe.best_params_]

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Интересно, что применяешь различные техники препроцессинга, молодец!

# %% [markdown]
# #### Логистическая регрессия с балансировкой весов c применением техники OHE и StandardScaler для кодирования и масштабирования данных

# %%
FPP = ('FPP', ColumnTransformer([
        ('num_features', make_pipeline(StandardScaler()), num_columns_list),
        ('cat_features', make_pipeline(OneHotEncoder(sparse=False, handle_unknown='ignore')), cat_columns_list)]))

LR = ('LR', LogisticRegression(random_state=STATE, class_weight='balanced'))

# зададим последовательность обработки
pipeline_LR = Pipeline(steps=[FPP, LR])

rs_lr_ss_ohe = RandomizedSearchCV(
    pipeline_LR, 
    param_distributions_lr, 
    n_iter=100, 
    cv=kf, 
    verbose=1,
    n_jobs=-1, 
    scoring='recall', 
    return_train_score=True, 
    random_state=STATE)

start_time = time.time()
rs_lr_ss_ohe.fit(features_train, target_train)
run_time = (time.time() - start_time) / 60

print(f'recall = {rs_lr_ss_ohe.best_score_:.4f}')

df_results.loc[len(df_results.index)] = ['Logistic Regression + OHE + Standart Scaler',
                                         rs_lr_ss_ohe.best_score_, run_time, rs_lr_ss_ohe.best_params_]

# %% [markdown]
# #### Логистическая регрессия с балансировкой весов c применением техники OrdinalEncoder и MinMaxScaler для кодирования и масштабирования данных

# %%
FPP = ('FPP', ColumnTransformer([
        ('num_features', make_pipeline(MinMaxScaler()), num_columns_list),
        ('cat_features', make_pipeline(OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)), cat_columns_list)]))

LR = ('LR', LogisticRegression(random_state=STATE, class_weight='balanced'))

# зададим последовательность обработки
pipeline_LR = Pipeline(steps=[FPP, LR])

rs_lr_mms_oe = RandomizedSearchCV(
    pipeline_LR, 
    param_distributions_lr, 
    n_iter=100, 
    cv=kf, 
    verbose=1,
    n_jobs=-1, 
    scoring='recall', 
    return_train_score=True, 
    random_state=STATE)

start_time = time.time()
rs_lr_mms_oe.fit(features_train, target_train)
run_time = (time.time() - start_time) / 60

print(f'recall = {rs_lr_mms_oe.best_score_:.4f}')

df_results.loc[len(df_results.index)] = ['Logistic Regression + OE + Min Max Scaler',
                                         rs_lr_mms_oe.best_score_, run_time, rs_lr_mms_oe.best_params_]

# %% [markdown]
# #### Обобщение результататов обучения

# %%
df_results

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Отлично, что сводишь все полученные результаты в таблицу.

# %% [markdown]
# Лучшие показатели метрики recall получились у модели Случайного леса с балансировкой весов и применением техники OrdinalEncoder для кодирования каттегориальных признаков и MinMaxScaler для масштабирования числовых признаков. Для предсказания на тестовых данных будем использовать именно эту модель. Проверим ёё на тестовой выборке. Изучим метрики модели, проверим её на адекватность.

# %% [markdown]
# #### Тестирование модели

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Отлично, что на тестовой выборке проверяешь только лучшую модель.

# %%
# получим предсказание модели на тестовой выборке
predicted_test = rs_rfc_mms_oe.best_estimator_.predict(features_test)

# получим оценки вероятности положительного исхода
rf_probs = rs_rfc_mms_oe.best_estimator_.predict_proba(features_test)[:, 1]

# %%
print(f'F1-мера  = {f1_score(target_test, predicted_test):.4f}')
print(f'ROC-AUC  = {roc_auc_score(target_test, rf_probs):.4f}')
print(f'Accuracy = {accuracy_score(target_test, predicted_test):.4f}')
print(f'Recall   = {recall_score(target_test, predicted_test):.4f}')

# %% [markdown]
# Построим ROC-кривую.

# %%
# выведем ROC-кривую
fpr, tpr, thresholds = roc_curve(target_test, rf_probs)
plt.figure(figsize=(15, 10))
plt.plot(fpr, tpr, label='MinMaxScaler + OrdinalEncoder + Random Forest')

# ROC-кривая случайной модели (выглядит как прямая)
plt.plot([0, 1], [0, 1], linestyle='--', label='RandomModel')

# установим границы осей от 0 до 1
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])

plt.xlabel('False Positive Rate', color='grey', weight = 'bold')
plt.ylabel('True Positive Rate', color='grey', weight = 'bold')
plt.title('ROC-кривая', weight = 'bold')
plt.legend()
plt.show()

# %% [markdown]
# Проверим модель на адекватность. Создадим baseline модель с помощью Dummy-классификатора. Рассчитаем для этой модели метрику recall и сравним её с нашей моделью.

# %%
dc = DummyClassifier(strategy='stratified', random_state=STATE)
dc.fit(features_train, target_train)
dc_pred = dc.predict(features_test)
dc_recall = recall_score(target_test, dc_pred)
# выведем результаты моделирования
print(f'Полнота для модели Dummy-классификатора на тестовой выборке: {dc_recall:.4f}')

# %% [markdown]
# В результате исследований мы получили модель с хорошими показателями метрик. Модель значительно лучше предсказывает, чем при использовании случайного предсказания. Доля правильных ответов нашей модели 0.6001, что значительно выше, чем у baseline модели 0.3707.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Отлично, что есть сравнение с константной моделью.

# %% [markdown]
# #### Оценка прибыли

# %%
data_test['arrival_date_month'].unique()

# %% [markdown]
# Прибыль от использования модели сеть отелей получит в том случае, когда реально произошла отмена бронирования, но модель предсказала такой случай и клиент внёс депозит в размере 80% от стоимости номера и затрат на уборку. Таким образом, прибыль от использования модели будет равна 80% от убытков, предсказанных отмен бронирования. Иными словами, если была отмена бронирования и модель её предсказала, то модель в этом случае сэкономит 80% , так как был внесён депозит. Так как тестовый период в нашем случае 8 месяцев, то для получения годовых показателей надо умножить полученные данные на 12:8 или на 1.5, таким образом вычислим потенциальные убытки и прибыли за год.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Молодец, что учитываешь этот момент.

# %%
profit_pred = abs((profit.loc[(data_test['is_canceled'] == 1) & (predicted_test == 1)] * DEPOSIT_SIZE).sum())

print(f'Прибыль сети отелей от внедрения модели за тестовый период: {profit_pred:,} руб.')
print(f'Годовая прибыль сети отелей от внедрения модели           : {profit_pred * 1.5:,} руб.')

# %%
if (profit_pred - BUDGET) > 0:
    print(f'Модель окупилась за тестовый период, прибыль с учётом затрат на разработку составила: {profit_pred - BUDGET:,} руб.')
    print(f'Годовая прибыль от внедрения модели c учётом затрат не разработку составит          : {profit_pred * 1.5 - BUDGET:,} руб.')
else:
    print(f'Модель не окупилась за тестовый период, убыток с учётом затрат на разработку составил: {profit_pred - BUDGET:,} руб.')

# %% [markdown]
# Отлично, модель окупилась.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Молодец, что учитываешь тот факт, что прибыль поменяется только в случае верного предсказания отмены брони.

# %% [markdown]
# #### Вывод по результатам шага

# %% [markdown]
# 1. На тренировочных данных были обучены 4 модели, в качестве метрики качества была выбрана полнота (recall), т.к. эта метрика показывает, какую долю объектов положительного класса из всех объектов положительного класса нашел алгоритм. Для снижения затрат нам как раз важно найти наибольшее количество тех, кто отменит бронирование и предложить им внести депозит.
# 2. Лучшие показатели метрики recall получились у модели Случайного леса с балансировкой весов и применением техники OrdinalEncoder для кодирования каттегориальных признаков и MinMaxScaler для масштабирования числовых признаков, при этом время на обучение у этой модели минимальное.
# 3. Модель с лучшим показателем recall была проверена на тестовых данных и резульататы были сравнены с baseline моделью. Наша модель значительно лучше предсказывает, чем при использовании случайного предсказания. О чем также говорит метрика ROC-AUC, которая находится на довольно высоком уровне 0.8295.
# 4. Оценена прибыль от внедрения модели. Модель вполне окупилась и принесла доп. прибыль.

# %% [markdown]
# ### Шаг 5. Опишите портрет «ненадёжного» клиента

# %% [markdown]
# Рассмотрим топ 5 признаков.

# %%
feature_importances = rs_rfc_mms_oe.best_estimator_._final_estimator.feature_importances_

plt.figure(figsize=(15, 10))
pd.Series(feature_importances, features_test.columns).nlargest(5).plot(kind='barh')
plt.title('Важнейшие признаки модели MinMaxScaler + OrdinalEncoder + Random Forest', weight = 'bold')
plt.show()

# %% [markdown]
# Все эти признаки анализировались ранее, на этапе исследовательского анализа. Основные наблюдения:

# %% [markdown]
# **Количество изменений параметров заказа (booking_changes)**
#
# - в данных присутствуют крайне редкие значения (свыше 1 изменения), но они яялются "выбросами" (лежащими за гарницами усов диаграммы размаха), но мы приняли подход не удалять такие данные, модель должна учиться работать с разными данными.
# - в основном клиенты (как отменившие, так и нет) не вносят изменений в бронь.
# - целом можно сделать следующий вывод, что чем больше у клиента изменений заказа, тем ниже шанс того, что он отменит заказ.

# %% [markdown]
# **Количество дней между датой бронирования и датой прибытия (lead_time)**
# - по реузльтатам статистического теста было установлена, что средние величины в двух классах различны, а следоватльено этот признак оказывает влиняие на факт "надежности" клиента
# - клиент, который бронирует сильно "заранее" не надежен

# %% [markdown]
# **Количество детей от 3 до 14 лет (children)**
# - на первый взгляд (на этапе ИАД) коилчество детей не оказывало влияние. Посмотрим чуть детальнее

# %%
pd.DataFrame(data_train.groupby('children')['is_canceled'].agg('mean')).sort_values('is_canceled', ascending=False)

# %% [markdown]
# В целом прослеживается след. связь, если ребенок 1, то шанс отказа от брони выше.

# %% [markdown]
# **День заезда (arrival_date_day_of_month)**
# - по результатам статистического теста, среднее значение в двух группа одинаковое, однако на гистограмме отчетливо видно, что в последний день месяца, количество клиентов отменявших бронь выше.
# - соответственно клиентов котоыре бронируют день заезда на последний в месяце можно считать не совсем надежными.

# %% [markdown]
# **Количество специальных отметок (total_of_special_requests)**
# - чем больше специальных отметок оставляет клиент, тем выше шанс, что от не отменит бронь
# - соответственно клиенты которые не оставляют отметок, в большей степени склонны к отмене бронирования

# %% [markdown]
# **Сформируем портрет не "надежного" клиента по топ 5 признакам**:
# 1. Клиент не вносит изменения в бронь
# 2. Клиент бронирует номер сильно заранее (более чем за 100 дней)
# 3. Клиент без детей или с 2 и более
# 4. Клиент бронирует заезд на послдений день месяца
# 5. Клиент не оставляет специальных отметок.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Молодец, что анализируешь важность признаков для модели в этом разделе.

# %% [markdown]
# ### Шаг 6. Напишите общий вывод

# %% [markdown]
# **Шаг 1** . Файлы (датасеты) с обучающей и тестовой выборками загружены и открыты без ошибок.
#
# **Шаг 2** . Выполнены этапы предпобработки и исследования данных.
#
# ***Для обучающей и тестовой выборок проведена предобработка данных***:
# - пропусков в данных не выявлено;
# - устновлено количество явных дубликатов более 20% от каждой из выборок, удалять их не правильных подход, во-первых цифра довольно большая и явно указывает на то, что дубликаты не случайны, во-вторых природа дубликатов не ясна и удаление их "в слепую" не самый удачный подход.
#
# ***Проведен исследовательский анализ целевого признака с прочими на обучающей выборке***:
# - исследован дисбаланс классов, соотношение 63% (не отменившие заказ) на 37% (отменившие заказ), дисабаласн нужно учесть при обучении модели;
# - по результатам исследования связи целевого признака с другими были установлены признаки котоыре влияют в большей степени (в т.ч. по результатам статистичесих тестов), так и не влияющие, темне-менее возможны не линейне зависимости с другими признаками;
# - в данных присутствуют выбросы (редкие значения), однако удалять их не будем, модель должна учиться работать с разными данными.
#
#
# **Шаг 3**. Оценена прибыль отеля без вндрения депозитов - 28,7 млн руб. Дополнительно проанализированы убытки отеля при отмене бронирования и результаты весьма не утешительные, убытки составли более 50% от прибыли.
#
# **Шаг 4.** Разработана модель ML:
# - На тренировочных данных были обучены 4 модели, в качестве метрики качества была выбрана полнота (recall), т.к. эта метрика показывает, какую долю объектов положительного класса из всех объектов положительного класса нашел алгоритм. Для снижения затрат нам как раз важно найти наибольшее количество тех, кто отменит бронирование и предложить им внести депозит.
# - Лучшие показатели метрики recall получились у модели Случайного леса с балансировкой весов и применением техники OrdinalEncoder для кодирования каттегориальных признаков и MinMaxScaler для масштабирования числовых признаков, при этом время на обучение у этой модели минимальное.
# - Модель с лучшим показателем recall была проверена на тестовых данных и резульататы были сравнены с baseline моделью. Наша модель значительно лучше предсказывает, чем при использовании случайного предсказания. О чем также говорит метрика ROC-AUC, которая находится на довольно высоком уровне 0.8295.
# - Оценена прибыль от внедрения модели. Модель вполне окупилась и принесла доп. прибыль.
#
# **Шаг 5.** Портрет не "надежного" клиента по топ 5 признакам:
# 1. Клиент не вносит изменения в бронь
# 2. Клиент бронирует номер сильно заранее (более чем за 100 дней)
# 3. Клиент без детей или с 2 и более
# 4. Клиент бронирует заезд на послдений день месяца
# 5. Клиент не оставляет специальных отметок.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Отличный содержательный резюмирующий вывод.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b>Общий вывод по проекту</b>
#
# Алексей, спасибо за работу! Проект хороший, продуманный, структурно выдержанный, аккуратный. Однако стоит внести некоторые исправления, чтобы можно было считать работу завершенной.
#
# **Положительные моменты проекта, которые хочу еще раз подчеркнуть:**
#
# 1. Есть первичный анализ данных
# 2. Есть описание клиента склонного к отмене брони
# 3. Предобработка данных проводится корректно
# 4. Исследовано 2 модели  ML
# 5. Есть обоснование выбора метрики
# 6. Расчет прибыли до и после внедрения системы депозитов верный
# 7. Для моделей подбираются оптимальные значения гиперпараметров
# 8. Качество моделей оценивается на кросс-валидации
# 9. На тестовой выборке проверяется только лучшая модель
# 10. Есть анализ баланса классов
# 11. Обучение моделей проводится с учетом дисбаланса
# 12. Подбирается оптимальный препроцессинг
#
#
#
# **Замечания, на которые стоит обратить внимание при будущей работе:**
#
#
# 1. Стоит исправить интерпретацию корреляционного анализа
#
# 2. Стоит исправить сезонные коэффициенты
#
#
#
# Остальные комментарии ты найдешь выше.
#
# **Желаю удачи и жду твой проект на повторное ревью!**

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b>Общий вывод по проекту №2</b>
#
# Алексей, спасибо за работу,
#
# **все отлично, проект принимаю и желаю успехов в дальнейшем!**
